# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
data=pd.read_csv("InsuranceDataSet.csv")
data
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
print(f"Data information:{data.info()}")
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      7 non-null      int64
#  1   Premium  7 non-null      int64
# dtypes: int64(2)
# memory usage: 244.0 bytes
# Data information:None
#              Age       Premium
# count   7.000000      7.000000
# mean   25.857143  20214.285714
# std     5.273474   6283.955382
# min    18.000000  10000.000000
# 25%    22.500000  16500.000000
# 50%    26.000000  21000.000000
# 75%    29.500000  25250.000000
# max    33.000000  27000.000000

# %%
#EDA
sns.jointplot(x='Age',y='Premium',data=data,alpha=0.5)

# %%
sns.lmplot(x="Age",y="Premium",data=data,scatter_kws={'alpha':0.4})

# %%
from sklearn.model_selection import train_test_split

# %%
x=data[["Age"]]
y=data["Premium"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#    Age
# 5   31
# 2   23
# 4   28
# 3   26
# 6   33

# %%
#Training the model
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(f"Model Coefficient:{model.coef_}")
print(f"Model intercept:{model.intercept_}")
# Out:
# Model Coefficient:[942.67515924]
# Model intercept:-3283.439490445864

# %%
#Predict using the test data
y_pred=model.predict(x_test)
y_pred
# Out:
# array([13684.7133758 , 17455.41401274])

# %%
#Evaluate the model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Evaluation:")
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R² Score:", r2)
# Out:
# Model Evaluation:
# Mean Absolute Error (MAE): 3070.0636942675155
# Mean Squared Error (MSE): 9803085.317862792
# Root Mean Squared Error (RMSE): 3130.9879140397193
# R² Score: -0.5684936508580467
